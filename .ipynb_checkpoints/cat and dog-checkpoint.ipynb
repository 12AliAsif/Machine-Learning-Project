# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# Load DataSets And Scale Data:

# %% [markdown]
# Preprocess Data

# %%
#Load the data from directory
data=tf.keras.utils.image_dataset_from_directory('data',image_size=(150, 150),shuffle=True)
# Out:
# Found 8002 files belonging to 2 classes.

# %%
#Normalize the data
data = data.map(lambda x,y:(x/255,y))
# Out:
# WARNING:tensorflow:From C:\Users\ZAH\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
s_iter=data.as_numpy_iterator()

# %%
batch=s_iter.next()

# %%
print(batch[0].max())
print(batch[0].min())
# Out:
# 1.0
# 0.0

# %%
#Plot the data
fig, ax=plt.subplots(ncols=10,figsize=(20,20))
for idx,img in enumerate(batch[0][:10]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# 1 is equal to Dog,
# 0 is equal to Cat

# %% [markdown]
# Split Data into Test and Train

# %%
len(data)
# Out:
# 251

# %%
#Splite the data into train set,validation set and test set
train_size=int(len(data)*.7)
val_size=int(len(data)*.2)
test_size=int(len(data)*.1)+1

# %%
test_size+train_size+val_size
# Out:
# 251

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# Deep Learning Model:

# %%
#Learning Model (the brain)
model = Sequential(
    [
        tf.keras.layers.Input(shape=(150,150,3)),
        Conv2D(100, (3,3), 1, activation='relu'),
        MaxPooling2D(),
        Conv2D(50, (3,3), 1, activation='relu'),
        MaxPooling2D(),
        Conv2D(16, (3,3), 1, activation='relu'),
        MaxPooling2D(),
        Conv2D(32, (3,3), 1, activation='relu'),
        MaxPooling2D(),
        Dropout(0.5),
        Flatten(),
        Dense(150,activation='relu'),
        Dense(50,activation='relu'),
        Dense(1,activation='sigmoid'),

])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 148, 148, 100)     2800
#
#  max_pooling2d_40 (MaxPoolin  (None, 74, 74, 100)      0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 72, 72, 50)        45050
#
#  max_pooling2d_41 (MaxPoolin  (None, 36, 36, 50)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 34, 34, 16)        7216
#
#  max_pooling2d_42 (MaxPoolin  (None, 17, 17, 16)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 15, 15, 32)        4640
#
#  max_pooling2d_43 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 7, 7, 32)          0
#
#  flatten_10 (Flatten)        (None, 1568)              0
#
#  dense_23 (Dense)            (None, 150)               235350
#
#  dense_24 (Dense)            (None, 50)                7550
#
#  dense_25 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 302,657
# Trainable params: 302,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='logs'

# %%
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist=model.fit(train,epochs=30,validation_data=val,callbacks=[tensorboard_callback],batch_size=32)
# Out:
# Epoch 1/30
# 175/175 [==============================] - 114s 641ms/step - loss: 0.6922 - accuracy: 0.5245 - val_loss: 0.6803 - val_accuracy: 0.5681
# Epoch 2/30
# 175/175 [==============================] - 133s 758ms/step - loss: 0.6593 - accuracy: 0.6116 - val_loss: 0.6759 - val_accuracy: 0.5669
# Epoch 3/30
# 175/175 [==============================] - 133s 761ms/step - loss: 0.6266 - accuracy: 0.6521 - val_loss: 0.6117 - val_accuracy: 0.6556
# Epoch 4/30
# 175/175 [==============================] - 136s 779ms/step - loss: 0.5896 - accuracy: 0.6909 - val_loss: 0.6038 - val_accuracy: 0.6725
# 175/175 [==============================] - 115s 659ms/step - loss: 0.1663 - accuracy: 0.9332 - val_loss: 0.5625 - val_accuracy: 0.7887
# Epoch 23/30
# 175/175 [==============================] - 114s 649ms/step - loss: 0.1640 - accuracy: 0.9377 - val_loss: 0.5411 - val_accuracy: 0.7944
# Epoch 24/30
# 175/175 [==============================] - 101s 578ms/step - loss: 0.1559 - accuracy: 0.9407 - val_loss: 0.5424 - val_accuracy: 0.7869
# Epoch 25/30
# 175/175 [==============================] - 113s 645ms/step - loss: 0.1331 - accuracy: 0.9518 - val_loss: 0.6010 - val_accuracy: 0.7962
# Epoch 26/30
# 175/175 [==============================] - 102s 579ms/step - loss: 0.1292 - accuracy: 0.9507 - val_loss: 0.6586 - val_accuracy: 0.7894
# Epoch 27/30
# 175/175 [==============================] - 115s 656ms/step - loss: 0.1244 - accuracy: 0.9523 - val_loss: 0.5707 - val_accuracy: 0.7975
# Epoch 28/30
# 175/175 [==============================] - 113s 648ms/step - loss: 0.1164 - accuracy: 0.9570 - val_loss: 0.6465 - val_accuracy: 0.7837
# Epoch 29/30
# 175/175 [==============================] - 102s 581ms/step - loss: 0.1079 - accuracy: 0.9618 - val_loss: 0.6685 - val_accuracy: 0.7875
# Epoch 30/30
# 175/175 [==============================] - 113s 647ms/step - loss: 0.1258 - accuracy: 0.9539 - val_loss: 0.6550 - val_accuracy: 0.7862

# %%
hist.history
# Out:
# {'loss': [0.69218909740448,
#   0.6592958569526672,
#   0.6265637278556824,
#   0.5895743370056152,
#   0.5617966651916504,
#   0.5322789549827576,
#   0.5019179582595825,
#   0.4837759733200073,
#   0.44797438383102417,
#   0.42598575353622437,
#   0.39117687940597534,
#   0.3536027669906616,
#   0.32817086577415466,
#   0.31773650646209717,
#   0.2808099091053009,
#   0.2525689899921417,
#   0.25261515378952026,
#   0.22151611745357513,
#   0.21869437396526337,
#   0.18480348587036133,
#   0.17181868851184845,
#   0.1663256585597992,
#   0.16397163271903992,
#   0.15587496757507324,
#   0.13311880826950073,
#   0.12923234701156616,
#   0.12442334741353989,
#   0.11644257605075836,
#   0.10787347704172134,
#   0.1258208155632019],
#  'accuracy': [0.5244643092155457,
#   0.6116071343421936,
#   0.6521428823471069,
#   0.6908928751945496,
#   0.706428587436676,
#   0.7341071367263794,
#   0.7562500238418579,
#   0.7632142901420593,
#   0.791607141494751,
#   0.7976785898208618,
#   0.818928599357605,
#   0.8430356979370117,
#   0.8535714149475098,
#   0.8617857098579407,
#   0.8762500286102295,
#   0.893928587436676,
#   0.8996428847312927,
#   0.910178542137146,
#   0.9119642972946167,
#   0.9253571629524231,
#   0.9298214316368103,
#   0.9332143068313599,
#   0.9376785755157471,
#   0.9407142996788025,
#   0.9517857432365417,
#   0.9507142901420593,
#   0.9523214101791382,
#   0.9569643139839172,
#   0.9617857336997986,
#   0.9539285898208618],
#  'val_loss': [0.6803365349769592,
#   0.6758877635002136,
#   0.6116888523101807,
#   0.6037781238555908,
#   0.5810520052909851,
#   0.5308091640472412,
#   0.5430799722671509,
#   0.5086748600006104,
#   0.48321378231048584,
#   0.48606595396995544,
#   0.48614633083343506,
#   0.4763845205307007,
#   0.49791109561920166,
#   0.49210125207901,
#   0.48303768038749695,
#   0.5001688599586487,
#   0.5091285705566406,
#   0.5046830177307129,
#   0.5571598410606384,
#   0.5405857563018799,
#   0.5620288252830505,
#   0.5625001788139343,
#   0.541090726852417,
#   0.5424080491065979,
#   0.6009546518325806,
#   0.6586356163024902,
#   0.5706854462623596,
#   0.6464671492576599,
#   0.6685370802879333,
#   0.6550039052963257],
#  'val_accuracy': [0.5681250095367432,
#   0.5668749809265137,
#   0.6556249856948853,
#   0.6725000143051147,
#   0.6943749785423279,
#   0.7387499809265137,
#   0.7325000166893005,
#   0.7537500262260437,
#   0.7631250023841858,
#   0.778124988079071,
#   0.7699999809265137,
#   0.778124988079071,
#   0.7562500238418579,
#   0.7674999833106995,
#   0.7912499904632568,
#   0.7837499976158142,
#   0.7799999713897705,
#   0.7900000214576721,
#   0.7787500023841858,
#   0.7956249713897705,
#   0.7806249856948853,
#   0.7887499928474426,
#   0.7943750023841858,
#   0.7868750095367432,
#   0.7962499856948853,
#   0.7893750071525574,
#   0.7975000143051147,
#   0.7837499976158142,
#   0.7875000238418579,
#   0.7862499952316284]}

# %% [markdown]
# Plot Performance:

# %%
fig=plt.figure()
plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')
fig.suptitle('Loss',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig=plt.figure()
plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')
fig.suptitle('accuracy',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Evaluate Performance:

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re= Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    x,y=batch
    yhat=model.predict(x)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 78ms/step

# %%
print(f'Precision{pre.result()},Recall{re.result()},Accuracy{acc.result()}')
# Out:
# Precision0.7219827771186829,Recall0.8502538204193115,Accuracy0.7655860185623169

# %% [markdown]
# Test:

# %%
img=cv2.imread('test_dir/24.JPG')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize=tf.image.resize(img,(150,150))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat=model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
yhat
# Out:
# array([[0.9996897]], dtype=float32)

# %%
if yhat > 0.5:
    print('This is a DOG')
else:
    print('This is a CAT')
# Out:
# This is a DOG

# %%
model.save(os.path.join('model','CatandDogmodel.h5'))

# %% [markdown]
# Save The Model

# %%
from tensorflow.keras.models import load_model

# %%
from keras import models    
model = models.load_model(os.path.join('model','CatandDogmodel.h5'))

# %% [markdown]
# Try Out some new example:

# %%
#You can try out some new example here
img=cv2.imread('test_dir/16.jpg') # change the numder of the .JPG
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize=tf.image.resize(img,(150,150))
#plt.imshow(resize.numpy().astype(int))
#plt.show()

# %%
y_predict=model.predict(np.expand_dims(resize/255,0))
y_predict
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.01162391]], dtype=float32)

# %%
if y_predict > 0.5:
    print('The Class Predicted is a Dog')
else:
    print('The Class Predicted is a Cat')
# Out:
# The Class Predicted is a Cat
